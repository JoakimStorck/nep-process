# %%
import json
with open("stats.json","r") as f:
    s=json.load(f)
print(s.get("counts",{}))
print(s.get("population",{}))
# Out:
# {'agents_seen': 12, 'births_life': 12, 'deaths_life': 3}
# {'pop_last': 9, 'pop_max': 12, 'pop_min': 9, 't_end_pop': 565.8799999997754}
